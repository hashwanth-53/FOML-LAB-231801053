# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load data from the SUV dataset CSV file
file_path = 'suv_data.csv' # Adjust the file name and path as necessary
data = pd.read_csv("suv_data.csv")

# Display the first few rows to help verify the data
print("First few rows of the dataset:")
print(data.head())

# Define the columns for the independent and dependent variables
x_column = 'Age' # Independent variable
y_column = 'EstimatedSalary' # Dependent variable

# Extract the specified columns and reshape x for model input
X = data[[x_column]].values # Note the double brackets to keep X as a 2D array
y = data[y_column].values

# Create and train the linear regression model
model = LinearRegression()
model.fit(X, y)

# Get the slope (coefficient) and intercept of the line
m = model.coef_[0] # Slope
c = model.intercept_ # Intercept
print("Slope (m):", m)
print("Intercept (c):", c)

# Predict y values for plotting the regression line
y_pred = model.predict(X)

# Plot the data points and the regression line
plt.scatter(X, y, color="blue", label="Data points")
plt.plot(X, y_pred, color="red", label="Regression line")
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title("Linear Regression on SUV Dataset")
plt.legend()
plt.show()
# Out:
# First few rows of the dataset:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# Slope (m): 504.9324471182234
# Intercept (c): 50729.2687037633
